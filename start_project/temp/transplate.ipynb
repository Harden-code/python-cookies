# %%
import Ask

# %%
picture=[f'{i}.png'for i in range(1,6)]
result=[]
message='''这是一张英文版的线性代数的习题图片,你帮我题目描述翻译成中文,返回格式如下:
```
英文翻译:1.What multiple £21?
中文翻译:£21乘数是
```
'''
for p in picture:
    result.append(Ask.ask_gpt_picture(p,message))

# %%
for i in range(len(result)):
    print(result[i].json()['choices'][0]['message']['content'])
# Out:
# ```
# 英文翻译: 1. What multiple ℓ21 of equation 1 should be subtracted from equation 2?
# 中文翻译: 1. 方程1的ℓ21倍数应从方程2中减去多少？
#
# 英文翻译: 2. Solve the triangular system of Problem 1 by back substitution, y before x. Verify that x times (2,10) plus y times (3,9) equals (1,11). If the right side changes to (4,44), what is the new solution?
# 中文翻译: 2. 通过回代法解问题1的三角系统，先求y再求x。验证x乘以(2,10)加上y乘以(3,9)等于(1,11)。如果右边变为(4,44)，新的解是什么？
#
# 英文翻译: 3. What multiple of equation 1 should be subtracted from equation 2?
# 中文翻译: 3. 方程1的多少倍应从方程2中减去？
#
# 英文翻译: 4. What multiple ℓ of equation 1 should be subtracted from equation 2 to remove c?
# 中文翻译: 4. 方程1的ℓ倍数应从方程2中减去以消除c？
#
# 英文翻译:  The first pivot is a (assumed nonzero). Elimination produces what formula for the second pivot? What is y? The second pivot is missing when ad = bc: singular.
# 中文翻译: 第一个主元是a（假设非零）。消元过程中第二个主元的公式是什么？y是多少？当ad = bc时第二个主元不存在：奇异。
# ```
# ```
# 英文翻译:11. (Recommended) A system of linear equations can't have exactly two solutions. Why?
# ...
