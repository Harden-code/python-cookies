# %% [markdown]
# ### 数
# complex number 复数
#
# real numbers 实数
#
# imaginary numbers 虚数
#
# the set of complex numbers 复数集
#
# rational numbers 有理数
#
# irrational number 无理数
#
# finite decimal,terminating decimal 有限小数
#
# repeating decimal,recurring decimal 无限循环小数
#
# decimal separator 小数点
#
# the square root of two 根号2

# %% [markdown]
# ### 加减
# addition 加法
#
# plus sign,plus symbols 加号
#
#
# 1+1=2
# - One plus one equals two.
# - The sum of one and one is two.
# - If you add one to one, you get two.
#
# 2+3=5
# - Two plus three equals five
# - Two plus three is equal to five
# - Three added to two makes five.
# - If you add two to three, you get five.
#
# substraction 减法
#
# inverse operation of addition 加法的逆运算
#
# minus sign 减号
#
# minuend 被减数
#
# substrahend 简数
#
# difference 差
#
# 5-3=2
# - Five minus three equals two
# - Five minus three is equal to two
# - Three subtracted from five equals two
# - If you subtract three from five, you get two.
# - If you take three from five, you get two
#
# 4-6=-2
# - Four minus six equals negative two
# - Four minus six is equal to negative two

# %% [markdown]
# ### 乘法表示
#
# multiplication 乘法
#
# multiplicand 被乘数
#
# multiplier 乘数
#
# times;multiplied by 乘
#
# Product 乘积
#
# Multiplicant * Multplier=Product
#
#
# 2*3=6
# - Two times three equals six.
# - Two multiplied by three equals six
# - Two cross three equals six
# - The product of two and three is six
# - If you multiply two by three, you get six.
#
# a·b=c
# - a times b equals c.
# - a multiplied by b equals c.
# - a dot b equals c.
# - The product of a and b is c.
#
# factorial 阶乘
#
# cumulative product 累积乘积

# %% [markdown]
# ### 除法
# division 除法
#
# reverse operation of multiplication 乘法的逆运算
#
# dividend,numerator 被除数
#
# over,divided by 除以
#
# divisor,denominator 数数
#
# quotient 商
#
# remainder 余数
#
# divident / divisor = quotient
#
# numerator / denominator = quotient
#
# 6/2=2
# - Six divided by three equals two
# - If you divide six by three you get two
#
# 7/2=3...1
# - Seven over two is three and the remainder is one.
# - Seven divided by two equals three with a remainder of one
# - Seven divided by two equals three and the remainder is one.

# %% [markdown]
# ### 分数
# fraction 分数
#
# common fraction,simple fraction 普通分数
#
# denominator 分母
#
# numerator 分子
#
# fraction bar 分数线
#
# forward slash 正斜杠
#
# nonzero integer 非0正数
#
# reciprocal 导数
#
#
# $\frac{1}{2}$
# - one half
# - a half
# - one over two
#
# 1:2
# - one to two
#
# $-\frac{3}{2}$
# - minus three-halves
# - nagative three-halves
#
# $\frac{1}{4}$
# - one over four
# - one fourth
# - one quarter
# - one divided by four
#
# $1\frac{1}{4}$
# - one and one fourth
#
# $\frac{1}{5}$
# - one fifth
#
# $\frac{1}{2}$
# - three fifths
#
# $\frac{1}{n}$
# - one over n
#
# $\frac{a}{b}$
# - a over b
# - a divided by b
# - the ratio of a to b
# - the numerator is a while the denominator is b

# %% [markdown]
# ### 其他
# commutative 交换律
#
# associative 结合律
#
# if and only if  当且仅当
